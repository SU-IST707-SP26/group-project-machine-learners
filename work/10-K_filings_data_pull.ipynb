# %% [markdown]
# # Import Needed Packages and then Pull Tickers from ESG Data

# %%
#%pip install sec-edgar-downloader
#%pip install pandas

# %% [markdown]
# # STEP 1: DOWNLOAD ALL FILINGS

# %%
from sec_edgar_downloader import Downloader
import pandas as pd
from datetime import datetime
import time

EMAIL       = "ecradeck@syr.edu"
ESG_PATH    = "../data/ESG_data.csv"
FILINGS_DIR = "../data/sec-filings"

df = pd.read_csv(ESG_PATH)
print(f"Loaded {len(df)} companies")

dl = Downloader("Syracuse University", EMAIL, download_folder=FILINGS_DIR)

success, failed = [], []

for ticker in df['ticker']:
    ticker_upper = ticker.upper()
    try:
        dl.get("10-K", ticker_upper, before=datetime(2022, 4, 1), limit=1)
        success.append(ticker_upper)
        print(f"✓ {ticker_upper}")
    except Exception as e:
        failed.append(ticker_upper)
        print(f"✗ {ticker_upper}: {e}")
    time.sleep(0.5)

print(f"\nSuccess: {len(success)}/{len(df)}")
print(f"Failed:  {len(failed)}")
print(f"Failed tickers: {failed}")
# Out:
# Loaded 722 companies
# ✓ DIS
# ✓ GM
# ✓ GWW
# ✓ MHK
# ✓ LYV
# ✓ LVS
# ✓ CLX
# ✓ AACG
# ✓ AAL
# ✓ AAME
# ✓ AAOI
# ✓ AAON
# ✓ AAPL
# ✓ AATC
# ✗ AAWW: Ticker 'AAWW' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ AACI
# ✗ AADI: Ticker 'AADI' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ ABEO
# ✓ ABNB
# ✗ ABIO: Ticker 'ABIO' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ ABMD: Ticker 'ABMD' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ ABOS
# ✓ ABSI
# ✗ ABTX: Ticker 'ABTX' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ ABUS
# ✓ ABVC
# ✓ ACAD
# ✗ ACAC: Ticker 'ACAC' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ ACCD: Ticker 'ACCD' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ ACET
# ✓ ABCL
# ✓ ABCB
# ✗ ACEV: Ticker 'ACEV' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ ACHL: Ticker 'ACHL' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ ACHC
# ✓ ACIW
# ✓ ACLS
# ✓ ACIU
# ✓ ACHV
# ✓ ACMR
# ✗ ACOR: Ticker 'ACOR' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ ACNB
# ✓ ACRS
# ✗ ACRX: Ticker 'ACRX' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ ACT
# ✓ ACTG
# ✓ ACVA
# ✓ ADAG
# ✓ ACXP
# ✓ ADBE
# ✗ ADAP: Ticker 'ADAP' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ ADMA
# ✗ ADES: Ticker 'ADES' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ ADI
# ✓ ADIL
# ✗ ADMP: Ticker 'ADMP' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ ACER: Ticker 'ACER' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ ADOC: Ticker 'ADOC' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ ADUS
# ✓ ACGL
# ✓ ADPT
# ✓ ADSK
# ✓ ADP
# ✓ ADTX
# ✓ ADV
# ✗ ADVM: Ticker 'ADVM' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ AEHR
# ✓ AEHL
# ✓ AEI
# ✓ AEIS
# ✓ AEP
# ✓ AEMD
# ✗ AESE: Ticker 'AESE' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ AEYE
# ✗ AERI: Ticker 'AERI' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ AEY: Ticker 'AEY' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ AFAQ: Ticker 'AFAQ' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ AFMD: Ticker 'AFMD' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ AFCG
# ✓ AFBI
# ✓ AFRM
# ✗ AFIB: Ticker 'AFIB' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ AGEN
# ✓ AFYA
# ✗ AGFS: Ticker 'AGFS' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ AGFY: Ticker 'AGFY' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ AGIL: Ticker 'AGIL' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ AGMH
# ✓ AGIO
# ✗ AGLE: Ticker 'AGLE' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ AGNC
# ✗ AGRI: Ticker 'AGRI' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ AGRX: Ticker 'AGRX' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ AGYS
# ✗ AGTC: Ticker 'AGTC' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ AHCO
# ✗ AHPI: Ticker 'AHPI' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ AIB
# ✓ ADTN
# ✗ ADN: Ticker 'ADN' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ AIKI: Ticker 'AIKI' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ AKIC: Ticker 'AKIC' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ AIP
# ✗ AKRO: Ticker 'AKRO' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ AIRT
# ✗ AIMC: Ticker 'AIMC' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ AKBA
# ✓ AIRG
# ✓ AIRS
# ✓ AKAM
# ✗ AKU: Ticker 'AKU' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ AKUS: Ticker 'AKUS' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ AKTS
# ✓ AKTX
# ✗ ALBO: Ticker 'ALBO' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ AKYA: Ticker 'AKYA' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ ALCO
# ✓ ALDX
# ✓ ALEC
# ✓ ALGM
# ✓ ALF
# ✓ ALGN
# ✓ ALGS
# ✓ ALHC
# ✓ ALKS
# ✗ ALIM: Ticker 'ALIM' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ ALGT
# ✗ AIH: Ticker 'AIH' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ ALKT
# ✓ ALNY
# ✓ ALLT
# ✓ ALLO
# ✓ AMAT
# ✓ AMD
# ✗ ATVI: Ticker 'ATVI' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ AVGO
# ✗ ANSS: Ticker 'ANSS' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ AMZN
# ✓ AIHS
# ✓ APA
# ✓ BIIB
# ✓ BKNG
# ✓ CDNS
# ✓ CDW
# ✓ CHRW
# ✓ CINF
# ✓ CHTR
# ✓ CMCSA
# ✓ CPRT
# ✓ COST
# ✓ CSX
# ✓ CTSH
# ✓ CME
# ✓ CSCO
# ✓ CTAS
# ✗ CTXS: Ticker 'CTXS' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ CZR
# ✗ DISH: Ticker 'DISH' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ DLTR
# ✓ DXCM
# ✓ EA
# ✓ LNT
# ✓ FANG
# ✓ EBAY
# ✓ LKQ
# ✓ GOOGL
# ✓ MAR
# ✓ MCHP
# ✓ LRCX
# ✓ MDLZ
# ✓ META
# ✓ MKTX
# ✓ MNST
# ✓ MRNA
# ✓ MTCH
# ✓ MPWR
# ✓ MSFT
# ✓ MU
# ✓ NDAQ
# ✗ NLOK: Ticker 'NLOK' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ NTRS
# ✓ NWL
# ✓ NVDA
# ✗ ALLK: Ticker 'ALLK' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ NWSA
# ✓ ODFL
# ✓ PCAR
# ✓ NXPI
# ✓ ORLY
# ✓ PAYX
# ✓ PFG
# ✓ ROST
# ✓ SBAC
# ✓ QCOM
# ✓ POOL
# ✓ PEP
# ✓ SBUX
# ✓ REG
# ✓ QRVO
# ✓ PTC
# ✓ PENN
# ✓ PYPL
# ✓ REGN
# ✓ AMGN
# ✓ SNPS
# ✓ STX
# ✓ TECH
# ✓ TER
# ✓ SWKS
# ✓ TRMB
# ✓ TROW
# ✓ TTWO
# ✓ TSLA
# ✓ TSCO
# ✓ TXN
# ✓ TMUS
# ✓ UAL
# ✓ VRSK
# ✓ ULTA
# ✓ VRTX
# ✓ VTRS
# ✓ VRSN
# ✗ WBA: Ticker 'WBA' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ NTAP
# ✓ XEL
# ✓ XRAY
# ✓ ZBRA
# ✓ AAP
# ✓ ZION
# ✓ WYNN
# ✓ A
# ✓ ABBV
# ✗ ABC: Ticker 'ABC' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ ADM
# ✓ ABT
# ✓ AEE
# ✓ AES
# ✓ AFL
# ✓ ACN
# ✓ AJG
# ✓ AIZ
# ✓ ALK
# ✓ ALB
# ✓ AIG
# ✓ ALL
# ✓ ALLE
# ✓ AMP
# ✓ AME
# ✓ AMT
# ✓ AOS
# ✓ APD
# ✓ AON
# ✓ ANET
# ✓ APH
# ✓ ATO
# ✓ AWK
# ✓ ARE
# ✓ APTV
# ✓ AVB
# ✓ AVY
# ✓ BA
# ✓ BAC
# ✓ BAX
# ✓ BBWI
# ✓ BDX
# ✓ BIO
# ✓ BBY
# ✓ BK
# ✓ AXP
# ✓ BR
# ✓ BMY
# ✓ BRO
# ✓ AZO
# ✓ BSX
# ✓ BX
# ✓ BXP
# ✗ SIVB: Ticker 'SIVB' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ C
# ✓ CAT
# ✓ CARR
# ✓ CBRE
# ✓ CCI
# ✗ CDAY: Ticker 'CDAY' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ CMA: Ticker 'CMA' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ DHI
# ✓ DOV
# ✓ DRI
# ✓ CE
# ✓ DG
# ✓ CMG
# ✓ DGX
# ✓ CCL
# ✓ CHD
# ✓ DOW
# ✗ DFS: Ticker 'DFS' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ DUK
# ✗ DRE: Ticker 'DRE' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ CF
# ✓ DVN
# ✓ ECL
# ✓ HD
# ✓ DTE
# ✓ EIX
# ✓ GLW
# ✓ DVA
# ✓ WDC
# ✓ GS
# ✓ DXC
# ✓ ETN
# ✓ ED
# ✓ HSY
# ✓ JNJ
# ✓ JPM
# ✓ KO
# ✓ KMX
# ✓ LDOS
# ✓ LEG
# ✓ MCD
# ✓ LIN
# ✓ LUMN
# ✓ LYB
# ✓ MCO
# ✓ MCK
# ✓ MAS
# ✓ LOW
# ✓ MDT
# ✓ MKC
# ✓ MET
# ✓ MGM
# ✗ MMC: Ticker 'MMC' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ MO
# ✓ BWA
# ✓ MRK
# ✗ MRO: Ticker 'MRO' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ MPC
# ✓ MS
# ✓ MTB
# ✓ MTD
# ✓ MSI
# ✓ NEE
# ✓ MSCI
# ✓ NCLH
# ✓ NI
# ✓ NOC
# ✓ NOW
# ✓ NUE
# ✗ NLSN: Ticker 'NLSN' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ NSC
# ✓ NVR
# ✓ PGR
# ✓ PFE
# ✓ PHM
# ✓ PH
# ✗ PKI: Ticker 'PKI' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ PLD
# ✓ PPG
# ✓ PSA
# ✓ PNC
# ✓ PM
# ✓ PKG
# ✓ PSX
# ✓ PRU
# ✓ PNR
# ✓ PNW
# ✓ PPL
# ✓ PWR
# ✓ RJF
# ✓ RF
# ✓ RCL
# ✓ RL
# ✓ PVH
# ✓ RHI
# ✗ PXD: Ticker 'PXD' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ ROL
# ✓ RMD
# ✓ SCHW
# ✓ ROK
# ✓ TDG
# ✓ SEE
# ✓ ROP
# ✓ SWK
# ✓ STZ
# ✓ SYK
# ✓ SYY
# ✓ SHW
# ✓ SPGI
# ✓ STE
# ✓ SYF
# ✓ SPG
# ✓ SRE
# ✓ SO
# ✓ STT
# ✓ SNA
# ✓ RTX
# ✓ HIG
# ✓ TEL
# ✓ TFX
# ✓ TFC
# ✓ TDY
# ✓ TGT
# ✓ TJX
# ✓ TPR
# ✓ TRV
# ✓ TMO
# ✓ TT
# ✓ TSN
# ✓ TYL
# ✓ TXT
# ✓ UNH
# ✓ UPS
# ✓ UDR
# ✓ UHS
# ✓ MOS
# ✓ USB
# ✓ URI
# ✓ VNO
# ✓ VLO
# ✓ VFC
# ✓ V
# ✓ VTR
# ✓ VMC
# ✓ WEC
# ✓ WELL
# ✓ WAT
# ✓ WM
# ✓ WAB
# ✓ WMB
# ✓ WFC
# ✓ WHR
# ✓ WST
# ✓ WRB
# ✓ WMT
# ✓ WU
# ✓ YUM
# ✓ XYL
# ✓ WY
# ✗ WRK: Ticker 'WRK' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ XOM
# ✓ ZBH
# ✓ ZTS
# ✓ DE
# ✓ DD
# ✓ D
# ✓ CVS
# ✓ DAL
# ✓ CRM
# ✓ CVX
# ✓ CTVA
# ✓ CTRA
# ✗ CTLT: Ticker 'CTLT' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ CPB
# ✓ CRL
# ✓ COP
# ✓ COO
# ✓ COF
# ✓ CNC
# ✓ CNP
# ✓ CMS
# ✓ CMI
# ✓ CL
# ✓ MMM
# ✓ CFG
# ✓ CAG
# ✓ CI
# ✓ CAH
# ✓ MA
# ✓ LW
# ✓ MAA
# ✓ MLM
# ✓ LUV
# ✓ LNC
# ✓ LEN
# ✓ PG
# ✓ OGN
# ✓ OXY
# ✓ DELL
# ✓ PAYC
# ✓ PEG
# ✓ OKE
# ✓ NRG
# ✓ L
# ✓ OMC
# ✓ ORCL
# ✓ O
# ✓ DPZ
# ✓ T
# ✓ UNP
# ✓ NEM
# ✓ FDX
# ✓ NKE
# ✓ F
# ✓ LMT
# ✓ RSG
# ✓ ENPH
# ✓ EXC
# ✓ EXPD
# ✓ EXPE
# ✓ FAST
# ✓ FFIV
# ✓ FISV
# ✓ EQIX
# ✓ FTNT
# ✓ ETSY
# ✓ BEN
# ✓ DLR
# ✓ DHR
# ✓ EFX
# ✓ EL
# ✓ EMN
# ✓ EMR
# ✓ EOG
# ✓ EQR
# ✓ ES
# ✓ ESS
# ✓ FITB
# ✓ ETR
# ✓ EXR
# ✓ EW
# ✓ FOXA
# ✓ FCX
# ✓ FE
# ✗ FLT: Ticker 'FLT' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ FIS
# ✗ FRC: Ticker 'FRC' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ FMC
# ✓ FRT
# ✓ FTV
# ✗ GPS: Ticker 'GPS' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ GRMN
# ✓ IT
# ✓ LLY
# ✗ RE: Ticker 'RE' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ EVRG
# ✗ FBHS: Ticker 'FBHS' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ GILD
# ✓ HOLX
# ✓ HSIC
# ✓ HON
# ✓ HST
# ✓ GD
# ✓ HAS
# ✓ HBAN
# ✓ GL
# ✓ GPC
# ✓ GNRC
# ✓ GPN
# ✓ HCA
# ✗ HBI: Ticker 'HBI' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ HII
# ✓ HPE
# ✗ HES: Ticker 'HES' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ HLT
# ✓ HRL
# ✓ HPQ
# ✓ HUM
# ✓ HWM
# ✗ PEAK: Ticker 'PEAK' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ GIS
# ✓ GE
# ✓ SPOT
# ✗ TRTN: Ticker 'TRTN' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ TRTX
# ✓ TRU
# ✓ YETI
# ✓ YELP
# ✓ YEXT
# ✗ SPR: Ticker 'SPR' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ YSG
# ✓ YRD
# ✓ YUMC
# ✓ TROX
# ✓ ZEPP
# ✗ ZEV: Ticker 'ZEV' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ ZUO: Ticker 'ZUO' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ ZIM
# ✓ ZYME
# ✓ ZWS
# ✓ YOU
# ✗ ZEN: Ticker 'ZEN' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ PLXS
# ✓ SHIP
# ✓ SHLS
# ✓ SHOO
# ✗ SHYF: Ticker 'SHYF' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ SIBN
# ✓ SIEB
# ✗ PLYA: Ticker 'PLYA' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ WWE: Ticker 'WWE' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ PMCB
# ✓ WWW
# ✓ XHR
# ✗ X: Ticker 'X' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ XPEV
# ✓ XPO
# ✗ XIN: Ticker 'XIN' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ XL: Ticker 'XL' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ XYF
# ✗ Y: Ticker 'Y' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ YALA
# ✓ WTS
# ✗ SIEN: Ticker 'SIEN' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ HAIN
# ✓ MTC
# ✗ MTCR: Ticker 'MTCR' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ MTEM: Ticker 'MTEM' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ MTLS
# ✓ MTEX
# ✓ MTRX
# ✓ HALO
# ✗ HALL: Ticker 'HALL' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ MVBF
# ✓ MVST
# ✓ MVIS
# ✓ MXCT
# ✓ MYGN
# ✓ MYFW
# ✓ MXL
# ✗ MYMD: Ticker 'MYMD' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ MYPS
# ✗ MTTR: Ticker 'MTTR' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ MTSI
# ✓ CLRO
# ✗ CLSN: Ticker 'CLSN' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ GURE
# ✗ GVP: Ticker 'GVP' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ GYRO
# ✓ GWRS
# ✗ HA: Ticker 'HA' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ CLSK
# ✗ CLSD: Ticker 'CLSD' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ HAAC: Ticker 'HAAC' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ HAFC
# ✓ CLST
# ✓ CLWT
# ✗ CLXT: Ticker 'CLXT' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ CMBM
# ✓ CMCO
# ✗ EVK: Ticker 'EVK' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ CLVS: Ticker 'CLVS' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ CLVR: Ticker 'CLVR' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ HAPP: Ticker 'HAPP' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ HBCP
# ✓ HBIO
# ✓ HBNC
# ✓ HBT
# ✓ HCAT
# ✗ HCAR: Ticker 'HCAR' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ HARP: Ticker 'HARP' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ HAYN: Ticker 'HAYN' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ PNBK
# ✗ HCDI: Ticker 'HCDI' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ HCCI: Ticker 'HCCI' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ PNFP
# ✗ PNT: Ticker 'PNT' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ POAI: Ticker 'POAI' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ POLA
# ✓ PODD
# ✓ POWI
# ✓ POWW
# ✓ PNRG
# ✓ PNTG
# ✗ PPBI: Ticker 'PPBI' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ PPIH
# ✓ PPC
# ✓ PRAA
# ✓ PPSI
# ✓ PRAX
# ✓ PRCT
# ✓ PRCH
# ✓ PRE
# ✓ PRDO
# ✓ SISI
# ✓ SITM
# ✓ SIRI
# ✓ SJ
# ✗ POW: Ticker 'POW' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ POWL
# ✓ UPWK
# ✗ USAK: Ticker 'USAK' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ USAU
# ✗ USAP: Ticker 'USAP' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ USEG
# ✓ USIO
# ✓ UTHR
# ✓ URGN
# ✓ URBN
# ✗ UTME: Ticker 'UTME' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✗ UTRS: Ticker 'UTRS' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ UTSI
# ✓ UXIN
# ✓ UVSP
# ✓ CMCM
# ✓ CMC
# ✓ USLM
# ✓ UTMD
# ✓ CMP
# ✗ CND: Ticker 'CND' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ CNF
# ✓ CNMD
# ✓ CNK
# ✓ CNNE
# ✓ CNO
# ✓ CNA
# ✓ CMRE
# ✓ GVA
# ✓ FN
# ✓ H
# ✓ HASI
# ✓ HAYW
# ✓ HBB
# ✓ HCC
# ✓ HCI
# ✓ HE
# ✓ GWRE
# ✓ HAE
# ✗ HEP: Ticker 'HEP' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ HGV
# ✓ HI
# ✗ HHC: Ticker 'HHC' is invalid and cannot be mapped to a CIK. Please enter a valid ticker or CIK.
# ✓ HUBS
# ✓ HESM
# ✓ HEI
#
# Success: 608/722
# Failed:  114
# Failed tickers: ['AAWW', 'AADI', 'ABIO', 'ABMD', 'ABTX', 'ACAC', 'ACCD', 'ACEV', 'ACHL', 'ACOR', 'ACRX', 'ADAP', 'ADES', 'ADMP', 'ACER', 'ADOC', 'ADVM', 'AESE', 'AERI', 'AEY', 'AFAQ', 'AFMD', 'AFIB', 'AGFS', 'AGFY', 'AGIL', 'AGLE', 'AGRI', 'AGRX', 'AGTC', 'AHPI', 'ADN', 'AIKI', 'AKIC', 'AKRO', 'AIMC', 'AKU', 'AKUS', 'ALBO', 'AKYA', 'ALIM', 'AIH', 'ATVI', 'ANSS', 'CTXS', 'DISH', 'NLOK', 'ALLK', 'WBA', 'ABC', 'SIVB', 'CDAY', 'CMA', 'DFS', 'DRE', 'MMC', 'MRO', 'NLSN', 'PKI', 'PXD', 'WRK', 'CTLT', 'FLT', 'FRC', 'GPS', 'RE', 'FBHS', 'HBI', 'HES', 'PEAK', 'TRTN', 'SPR', 'ZEV', 'ZUO', 'ZEN', 'SHYF', 'PLYA', 'WWE', 'X', 'XIN', 'XL', 'Y', 'SIEN', 'MTCR', 'MTEM', 'HALL', 'MYMD', 'MTTR', 'CLSN', 'GVP', 'HA', 'CLSD', 'HAAC', 'CLXT', 'EVK', 'CLVS', 'CLVR', 'HAPP', 'HCAR', 'HARP', 'HAYN', 'HCDI', 'HCCI', 'PNT', 'POAI', 'PPBI', 'POW', 'USAK', 'USAP', 'UTME', 'UTRS', 'CND', 'HEP', 'HHC']

# %% [markdown]
# # STEP 2: EXTRACTION FUNCTIONS

# %%
from bs4 import BeautifulSoup
import re

FILINGS_BASE = "../data/sec-filings/sec-edgar-filings"

def load_filing_text(file_path):
    """Read a full-submission.txt file and return cleaned plain text."""
    with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
        content = f.read()
    try:
        soup = BeautifulSoup(content, 'html.parser')
    except Exception:
        return None
    text = soup.get_text()
    return ' '.join(text.split())


def extract_section(text, pattern, next_pattern):
    """Take the second match to skip TOC, extract until the next section begins."""
    matches = list(re.finditer(pattern, text, re.IGNORECASE))
    if len(matches) >= 2:
        m = matches[1]
    elif len(matches) == 1:
        m = matches[0]
    else:
        return None

    start = m.start()

    next_match = re.search(next_pattern, text[start + 100:], re.IGNORECASE)
    if next_match:
        end = start + 100 + next_match.start()
    else:
        end = len(text)

    return text[start:end]


def extract_business(text):
    return extract_section(text, r'ITEM\s*1\.\s*BUSINESS', r'ITEM\s*1A\.')

def extract_risk_factors(text):
    return extract_section(text, r'ITEM\s*1A\.\s*RISK\s*FACTORS', r'ITEM\s*1B\.')

def extract_mda(text):
    return extract_section(text, r'ITEM\s*7\.\s*MANAGEMENT', r'ITEM\s*7A\.')


def extract_all_sections(file_path):
    """Run all three extractors on a single filing file."""
    text = load_filing_text(file_path)
    if text is None:
        return {'business': None, 'risk_factors': None, 'mda': None}
    return {
        'business':     extract_business(text),
        'risk_factors': extract_risk_factors(text),
        'mda':          extract_mda(text)
    }

print("Extraction functions loaded.")
# Out:
# Extraction functions loaded.

# %% [markdown]
# # STEP 3: TEST EXTRACTION ON MSFT

# %%
import glob

files = glob.glob(f"{FILINGS_BASE}/MSFT/10-K/*/full-submission.txt")

if not files:
    print("MSFT filing not found — make sure Cell 1 ran successfully.")
else:
    sections = extract_all_sections(files[0])

    print(f"Extracted {sum(v is not None for v in sections.values())}/3 sections\n")

    for name, text in sections.items():
        if text:
            print(f"{name.upper()}: {len(text):,} characters")
            print(f"  First 200: {text[:200]}")
            print(f"  Last 200:  {text[-200:]}")
        else:
            print(f"{name.upper()}: NOT FOUND")
        print()
# Out:
# Extracted 3/3 sections
#
# BUSINESS: 74,757 characters
#   First 200: ITEM 1. BUSINESS GENERAL Embracing Our Future Microsoft is a technology company whose mission is to empower every person and every organization on the planet to achieve more. We strive to create local
#   Last 200:  stors. We encourage investors, the media, and others interested in Microsoft to review the information we post on the social media channels listed on our Investor Relations website. 21 PART I Item 1A
#
# RISK_FACTORS: 68,581 characters
#   First 200: ITEM 1A. RISK FACTORS Our operations and financial results are subject to various risks and uncertainties, including those described below, that could adversely affect our business, financial conditio
#   Last 200:  loyment-related laws are interpreted and applied to our workforce practices may result in increased operating costs and less flexibility in how we meet our workforce needs. 35 PART I Item 1B, 2, 3, 4
#
# MDA: 55,571 characters
#   First 200: ITEM 7. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS The following Management’s Discussion and Analysis of Financial Condition and Results of Operations (“MD&A
#   Last 200:  mmittee. Satya Nadella Chief Executive Officer Amy E. Hood Executive Vice President and Chief Financial Officer Alice L. Jolla Corporate Vice President and Chief Accounting Officer 55 PART II Item 7A

# %% [markdown]
# # STEP 4: FULL EXTRACTION LOOP

# %%
import glob
import os
import json
from concurrent.futures import ThreadPoolExecutor, as_completed

OUTPUT_DIR = "../data/extracted_sections"
os.makedirs(OUTPUT_DIR, exist_ok=True)

def process_ticker(ticker):
    files = glob.glob(f"{FILINGS_BASE}/{ticker}/10-K/*/full-submission.txt")
    if not files:
        return ticker, 'no_file', 0
    sections = extract_all_sections(files[0])
    n = sum(v is not None for v in sections.values())
    if n == 0:
        return ticker, 'no_sections', 0
    out_path = os.path.join(OUTPUT_DIR, f"{ticker}.json")
    with open(out_path, 'w') as f:
        json.dump({"ticker": ticker, "sections": sections}, f)
    return ticker, 'ok', n

extract_success, extract_partial, extract_failed = [], [], []

with ThreadPoolExecutor(max_workers=4) as executor:
    futures = {executor.submit(process_ticker, t): t for t in success}
    for future in as_completed(futures):
        ticker, status, n = future.result()
        if status in ('no_file', 'no_sections'):
            extract_failed.append(ticker)
            print(f"✗ {ticker}: {status}")
        elif n < 3:
            extract_partial.append(ticker)
            print(f"⚠ {ticker}: {n}/3 sections")
        else:
            extract_success.append(ticker)
            print(f"✓ {ticker}: 3/3 sections")

print(f"\n{'='*40}")
print(f"Full extractions (3/3): {len(extract_success)}")
print(f"Partial extractions:    {len(extract_partial)}")
print(f"Failed:                 {len(extract_failed)}")
print(f"\nPartial tickers: {extract_partial}")
print(f"Failed tickers:  {extract_failed}")
# Out:
# ✗ AACG: no_file
# ✗ GWW: no_sections
# ✓ MHK: 3/3 sections
# ✗ LVS: no_sections
# ✓ DIS: 3/3 sections
# ✓ GM: 3/3 sections
# ✓ AAPL: 3/3 sections
# ✗ AACI: no_file
# ✓ AATC: 3/3 sections
# ✓ AAON: 3/3 sections
# ✓ ABEO: 3/3 sections
# ✓ ABOS: 3/3 sections
# ✓ ABNB: 3/3 sections
# ✓ ABSI: 3/3 sections
# ✓ ABUS: 3/3 sections
# ✓ ABVC: 3/3 sections
# ✓ ACAD: 3/3 sections
# ✓ ABCL: 3/3 sections
# ✓ ACET: 3/3 sections
# ✓ ACIW: 3/3 sections
# ✓ ABCB: 3/3 sections
# ✗ ACIU: no_file
# ✓ AAOI: 3/3 sections
# ✓ ACMR: 3/3 sections
# ✗ AAME: no_sections
# ✓ ACRS: 3/3 sections
# ✓ ACLS: 3/3 sections
# ✓ ACHV: 3/3 sections
# ⚠ CLX: 2/3 sections
# ✗ ADAG: no_file
# ✓ ACTG: 3/3 sections
# ✓ ACVA: 3/3 sections
# ✓ ACT: 3/3 sections
# ✓ ACXP: 3/3 sections
# ✓ ADBE: 3/3 sections
# ✓ ADIL: 3/3 sections
# ✓ ADI: 3/3 sections
# ✓ ADPT: 3/3 sections
# ✓ ADSK: 3/3 sections
# ✓ ACGL: 3/3 sections
# ✗ LYV: no_sections
# ✓ ADTX: 3/3 sections
# ✓ ADP: 3/3 sections
# ✗ AEHL: no_file
# ✓ AAL: 3/3 sections
# ✓ AEHR: 3/3 sections
# ✓ ADV: 3/3 sections
# ✓ AEIS: 3/3 sections
# ✓ AEI: 3/3 sections
# ✓ ADMA: 3/3 sections
# ✓ ACHC: 3/3 sections
# ✓ AFCG: 3/3 sections
# ✓ AFBI: 3/3 sections
# ✗ AFYA: no_file
# ✗ AGMH: no_file
# ✓ AFRM: 3/3 sections
# ✓ AGEN: 3/3 sections
# ✓ AGIO: 3/3 sections
# ✓ AGYS: 3/3 sections
# ✗ AIB: no_file
# ✓ AGNC: 3/3 sections
# ⚠ AEMD: 2/3 sections
# ✓ AIP: 3/3 sections
# ✓ AEYE: 3/3 sections
# ✓ AIRT: 3/3 sections
# ✓ ADTN: 3/3 sections
# ✓ AIRG: 3/3 sections
# ✗ AKTS: no_file
# ✓ AIRS: 3/3 sections
# ✓ AEP: 3/3 sections
# ✓ ADUS: 3/3 sections
# ✓ AKTX: 3/3 sections
# ✓ ALDX: 3/3 sections
# ✗ ALF: no_file
# ✓ AKBA: 3/3 sections
# ✓ ALEC: 3/3 sections
# ✓ ALGM: 3/3 sections
# ✓ ALCO: 3/3 sections
# ✓ ALGS: 3/3 sections
# ✓ ALGN: 3/3 sections
# ✓ ALHC: 3/3 sections
# ✗ ALLT: no_file
# ✓ ALKT: 3/3 sections
# ✓ ACNB: 3/3 sections
# ✓ ALKS: 3/3 sections
# ✓ ALNY: 3/3 sections
# ✓ ALGT: 3/3 sections
# ✓ ALLO: 3/3 sections
# ✓ AMD: 3/3 sections
# ✗ AMAT: no_sections
# ✓ AVGO: 3/3 sections
# ✗ APA: no_sections
# ✓ AIHS: 3/3 sections
# ✓ BIIB: 3/3 sections
# ✓ CDNS: 3/3 sections
# ✓ BKNG: 3/3 sections
# ✓ CHRW: 3/3 sections
# ✓ CDW: 3/3 sections
# ✓ CHTR: 3/3 sections
# ✗ CMCSA: no_sections
# ✓ CPRT: 3/3 sections
# ✓ COST: 3/3 sections
# ✓ CINF: 3/3 sections
# ✓ CSX: 3/3 sections
# ✓ CME: 3/3 sections
# ✓ CTAS: 3/3 sections
# ✓ CTSH: 3/3 sections
# ✓ CSCO: 3/3 sections
# ✓ DLTR: 3/3 sections
# ✓ DXCM: 3/3 sections
# ✓ CZR: 3/3 sections
# ✓ LNT: 3/3 sections
# ✓ AKAM: 3/3 sections
# ✓ EBAY: 3/3 sections
# ✓ LKQ: 3/3 sections
# ✓ GOOGL: 3/3 sections
# ✓ MAR: 3/3 sections
# ✓ LRCX: 3/3 sections
# ✓ MCHP: 3/3 sections
# ✓ META: 3/3 sections
# ✓ MDLZ: 3/3 sections
# ✓ AMZN: 3/3 sections
# ✓ MKTX: 3/3 sections
# ✓ MNST: 3/3 sections
# ✓ MRNA: 3/3 sections
# ✓ MTCH: 3/3 sections
# ✓ MPWR: 3/3 sections
# ✓ MU: 3/3 sections
# ✓ NDAQ: 3/3 sections
# ✓ NVDA: 3/3 sections
# ✓ NWL: 3/3 sections
# ✓ ODFL: 3/3 sections
# ⚠ NTRS: 1/3 sections
# ✓ NXPI: 3/3 sections
# ✓ PCAR: 3/3 sections
# ✓ ORLY: 3/3 sections
# ✗ EA: no_sections
# ✓ PAYX: 3/3 sections
# ✓ ROST: 3/3 sections
# ✓ POOL: 3/3 sections
# ✓ AHCO: 3/3 sections
# ✓ PEP: 3/3 sections
# ✓ SBUX: 3/3 sections
# ✓ PFG: 3/3 sections
# ✓ QRVO: 3/3 sections
# ✓ PTC: 3/3 sections
# ✓ REG: 3/3 sections
# ✓ PYPL: 3/3 sections
# ✓ REGN: 3/3 sections
# ✓ QCOM: 3/3 sections
# ✓ AMGN: 3/3 sections
# ✓ SNPS: 3/3 sections
# ✗ FANG: no_sections
# ✓ STX: 3/3 sections
# ✓ TECH: 3/3 sections
# ✓ TRMB: 3/3 sections
# ✓ TROW: 3/3 sections
# ✓ TER: 3/3 sections
# ✓ TTWO: 3/3 sections
# ✓ MSFT: 3/3 sections
# ✓ TSCO: 3/3 sections
# ✓ TSLA: 3/3 sections
# ✓ UAL: 3/3 sections
# ✓ TMUS: 3/3 sections
# ✓ VRSK: 3/3 sections
# ✓ ULTA: 3/3 sections
# ✓ SWKS: 3/3 sections
# ✓ VRTX: 3/3 sections
# ✓ VRSN: 3/3 sections
# ✓ NTAP: 3/3 sections
# ✓ VTRS: 3/3 sections
# ✓ SBAC: 3/3 sections
# ✓ AAP: 3/3 sections
# ✓ ZBRA: 3/3 sections
# ✗ XEL: no_sections
# ✗ XRAY: no_sections
# ✓ A: 3/3 sections
# ✓ WYNN: 3/3 sections
# ✓ ZION: 3/3 sections
# ✓ ADM: 3/3 sections
# ✓ ABBV: 3/3 sections
# ✓ NWSA: 3/3 sections
# ✓ ACN: 3/3 sections
# ✓ AES: 3/3 sections
# ✓ AFL: 3/3 sections
# ✓ AEE: 3/3 sections
# ✓ AIZ: 3/3 sections
# ✓ TXN: 3/3 sections
# ✓ ALK: 3/3 sections
# ✓ ALB: 3/3 sections
# ✓ ALLE: 3/3 sections
# ✓ AME: 3/3 sections
# ✗ ALL: no_sections
# ✓ AMP: 3/3 sections
# ✓ AOS: 3/3 sections
# ✓ ANET: 3/3 sections
# ✓ AON: 3/3 sections
# ✓ APD: 3/3 sections
# ✓ APH: 3/3 sections
# ✓ AMT: 3/3 sections
# ✓ ATO: 3/3 sections
# ✓ AWK: 3/3 sections
# ✓ AIG: 3/3 sections
# ✓ APTV: 3/3 sections
# ✓ AVY: 3/3 sections
# ✓ ARE: 3/3 sections
# ✓ BA: 3/3 sections
# ✓ BAX: 3/3 sections
# ✓ BBWI: 3/3 sections
# ✓ BDX: 3/3 sections
# ✓ BIO: 3/3 sections
# ✓ BBY: 3/3 sections
# ✓ AXP: 3/3 sections
# ✓ BR: 3/3 sections
# ✗ BK: no_sections
# ✓ PENN: 3/3 sections
# ✓ ABT: 3/3 sections
# ✓ AZO: 3/3 sections
# ✓ BAC: 3/3 sections
# ✓ BMY: 3/3 sections
# ✓ BRO: 3/3 sections
# ✓ BSX: 3/3 sections
# ✓ CARR: 3/3 sections
# ✓ BXP: 3/3 sections
# ✓ CBRE: 3/3 sections
# ✓ CAT: 3/3 sections
# ✓ DHI: 3/3 sections
# ✓ CCI: 3/3 sections
# ✓ BX: 3/3 sections
# ✓ DRI: 3/3 sections
# ✓ DOV: 3/3 sections
# ✓ DG: 3/3 sections
# ✓ CMG: 3/3 sections
# ✓ CE: 3/3 sections
# ✓ DGX: 3/3 sections
# ✓ CHD: 3/3 sections
# ✗ C: no_sections
# ✓ CCL: 3/3 sections
# ✓ DOW: 3/3 sections
# ✓ HD: 3/3 sections
# ⚠ DVN: 2/3 sections
# ⚠ EIX: 1/3 sections
# ✓ AJG: 3/3 sections
# ✓ GLW: 3/3 sections
# ⚠ DTE: 2/3 sections
# ✓ DVA: 3/3 sections
# ✗ DUK: no_sections
# ✓ WDC: 3/3 sections
# ✓ HSY: 3/3 sections
# ✓ DXC: 3/3 sections
# ✓ JNJ: 3/3 sections
# ✗ ED: no_sections
# ✓ KMX: 3/3 sections
# ✓ KO: 3/3 sections
# ✓ GS: 3/3 sections
# ✓ LDOS: 3/3 sections
# ✓ JPM: 3/3 sections
# ✗ MCD: no_sections
# ✓ LEG: 3/3 sections
# ✓ LIN: 3/3 sections
# ⚠ LYB: 2/3 sections
# ✓ MCO: 3/3 sections
# ✓ MCK: 3/3 sections
# ✓ MAS: 3/3 sections
# ✓ LOW: 3/3 sections
# ✓ MKC: 3/3 sections
# ✓ MDT: 3/3 sections
# ✓ MGM: 3/3 sections
# ✓ MO: 3/3 sections
# ✓ BWA: 3/3 sections
# ✓ MET: 3/3 sections
# ✓ MRK: 3/3 sections
# ✓ MPC: 3/3 sections
# ✓ AVB: 3/3 sections
# ✓ MTD: 3/3 sections
# ✗ MS: no_sections
# ✓ MSI: 3/3 sections
# ✓ NEE: 3/3 sections
# ✓ CF: 3/3 sections
# ✓ MTB: 3/3 sections
# ✓ MSCI: 3/3 sections
# ✓ NOC: 3/3 sections
# ✓ NOW: 3/3 sections
# ✓ NUE: 3/3 sections
# ✓ NI: 3/3 sections
# ✓ NVR: 3/3 sections
# ✓ NSC: 3/3 sections
# ✓ NCLH: 3/3 sections
# ⚠ PHM: 2/3 sections
# ✗ PGR: no_sections
# ✓ PFE: 3/3 sections
# ✓ PPG: 3/3 sections
# ✓ PSA: 3/3 sections
# ✓ PLD: 3/3 sections
# ✓ PKG: 3/3 sections
# ✓ PM: 3/3 sections
# ✗ PNC: no_sections
# ⚠ PSX: 2/3 sections
# ✓ PNR: 3/3 sections
# ✓ ETN: 3/3 sections
# ✓ PNW: 3/3 sections
# ✓ PWR: 3/3 sections
# ⚠ PPL: 2/3 sections
# ✓ RJF: 3/3 sections
# ✓ RCL: 3/3 sections
# ✓ RF: 3/3 sections
# ✓ RHI: 3/3 sections
# ✓ RL: 3/3 sections
# ✓ PVH: 3/3 sections
# ✓ ROL: 3/3 sections
# ✗ RMD: no_sections
# ✓ ROK: 3/3 sections
# ✓ SCHW: 3/3 sections
# ✓ TDG: 3/3 sections
# ✗ LUMN: no_sections
# ✓ ROP: 3/3 sections
# ✓ SEE: 3/3 sections
# ✓ SWK: 3/3 sections
# ✓ STZ: 3/3 sections
# ✓ SYK: 3/3 sections
# ✓ SHW: 3/3 sections
# ✓ SYY: 3/3 sections
# ✓ SPGI: 3/3 sections
# ✓ SYF: 3/3 sections
# ✓ PH: 3/3 sections
# ✓ SPG: 3/3 sections
# ✓ ECL: 3/3 sections
# ✓ STT: 3/3 sections
# ✗ SNA: no_sections
# ✓ RTX: 3/3 sections
# ✓ SRE: 3/3 sections
# ✓ TFX: 3/3 sections
# ✓ TEL: 3/3 sections
# ✓ TGT: 3/3 sections
# ✓ TFC: 3/3 sections
# ✓ TPR: 3/3 sections
# ✓ HIG: 3/3 sections
# ✓ TT: 3/3 sections
# ✓ TRV: 3/3 sections
# ✓ TYL: 3/3 sections
# ✓ TSN: 3/3 sections
# ✓ TXT: 3/3 sections
# ✓ UNH: 3/3 sections
# ✓ UPS: 3/3 sections
# ✓ UDR: 3/3 sections
# ✓ UHS: 3/3 sections
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # STEP 5: VERIFICATION

# %%
import json
import os
import pandas as pd

OUTPUT_DIR = "../data/extracted_sections"

records = []

for fname in os.listdir(OUTPUT_DIR):
    if not fname.endswith(".json"):
        continue

    with open(os.path.join(OUTPUT_DIR, fname)) as f:
        data = json.load(f)

    ticker   = data['ticker']
    sections = data['sections']

    records.append({
        'ticker':         ticker,
        'business_chars': len(sections['business'])     if sections['business']     else 0,
        'risk_chars':     len(sections['risk_factors'])  if sections['risk_factors'] else 0,
        'mda_chars':      len(sections['mda'])           if sections['mda']          else 0,
        'sections_found': sum(v is not None for v in sections.values())
    })

audit_df = pd.DataFrame(records).sort_values('ticker').reset_index(drop=True)

# ── Summary stats ─────────────────────────────────────────────────────────────
print("=== Section Size Summary (characters) ===")
for col, label in [('business_chars', 'BUSINESS'), ('risk_chars', 'RISK FACTORS'), ('mda_chars', 'MD&A')]:
    s = audit_df[col][audit_df[col] > 0]
    print(f"\n{label}")
    print(f"  Mean:   {s.mean():>10,.0f}")
    print(f"  Median: {s.median():>10,.0f}")
    print(f"  Min:    {s.min():>10,.0f}")
    print(f"  Max:    {s.max():>10,.0f}")

# ── Coverage ──────────────────────────────────────────────────────────────────
print(f"\n=== Extraction Coverage ===")
for n in [3, 2, 1, 0]:
    count = (audit_df['sections_found'] == n).sum()
    print(f"  {n}/3 sections found: {count} companies")

# ── Flag partial extractions ──────────────────────────────────────────────────
partial = audit_df[audit_df['sections_found'] < 3]
if not partial.empty:
    print(f"\n=== Partial Extractions ({len(partial)} companies) ===")
    print(partial[['ticker', 'sections_found', 'business_chars', 'risk_chars', 'mda_chars']].to_string(index=False))

audit_df
